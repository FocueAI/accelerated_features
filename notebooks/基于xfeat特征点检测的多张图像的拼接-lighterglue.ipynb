# %%
import numpy as np
import os,sys
import torch
import tqdm
import cv2
import matplotlib.pyplot as plt
import pathlib

current_directory = os.getcwd()
__dir__ = pathlib.Path(current_directory)
sys.path.append(str(__dir__.parent))


from modules.xfeat import XFeat

weight_path = r'/mnt/disk3/projects/expore/accelerated_features/weights/xfeat.pt'
# weight_path = r'/mnt/disk3/projects/expore/accelerated_features/content/ckpts_1_23/xfeat_synthetic_160000.pth'
# xfeat = XFeat(weights=weight_path)
xfeat = XFeat()
# Out:
# loading weights from: /mnt/disk3/projects/expore/accelerated_features/modules/../weights/xfeat.pt

# %%
class stitcher:
    @staticmethod
    def detect(cv_im_bgr):
        ################################################### 
        res = xfeat.detectAndCompute(cv_im_bgr)[0]
        kps, features = res["keypoints"], res["descriptors"]
        
        return kps, features
    @staticmethod
    def match(src_cv_img, dst_cv_img, threshold=3.0):
        # ------------------------------- begin ------------------------------------
        kps1, feats1 = stitcher.detect(src_cv_img)
        kps2, feats2 = stitcher.detect(dst_cv_img)
        
        src_key_info = {
           "keypoints" : kps1,
           "descriptors" : feats1,
           "image_size" : src_cv_img.shape[:2],
        }
        dst_key_info = {
            "keypoints" : kps2,
            "descriptors" : feats2,
            "image_size" : dst_cv_img.shape[:2],
        }
        
        res = xfeat.match_lighterglue(src_key_info, dst_key_info)
        
        print(res)
        
        src_index, dst_index = xfeat.match(feats1, feats2, min_cossim = 0.98)
        src_points, dst_points = kps1[src_index].cpu().numpy(), kps2[dst_index].cpu().numpy()
        H, status = cv2.findHomography(src_points, # 源图像上的点集
                                dst_points, # 目标图像上的点集
                                cv2.RANSAC, threshold)
        # 其中 H 表示源图像到目标图像的变换矩阵
        return H

    @staticmethod
    def match_keypoints(kps1,kps2,matches,ratio,threshold):
        
        # step1: 筛选匹配点
        good_l,matches_l = [], []
        for match in matches:
            #                            可见匹配的2个点还是有从 优秀-->次优秀排序的。 
            #                            如果ratio=0.8，那么对于一个（最优）匹配点，只有当它和它的下一个匹配点（次优）距离小于它的前一个匹配点距离的0.8倍时，才被保留。
            if len(match) == 2 and match[0].distance < match[1].distance * ratio:
                good_l.append(match[0])
                matches_l.append((match[0].queryIdx, match[0].trainIdx)) # （查询图像中点的索引，训练图像中点的索引）
        
        # 当匹配的特征点对数 > 4,就可以用来构建变换矩阵了
        
        kps1_coors = np.float32([kpt.pt for kpt in kps1]).tolist()
        kps2_coors = np.float32([kpt.pt for kpt in kps2]).tolist()
        print(f"len(good_l):{len(good_l)}")
        if len(good_l) > 4:
           match_kp1_l =  [kps1_coors[match[0]] for match in matches_l]
           match_kp2_l =  [kps2_coors[match[1]] for match in matches_l]
           # 计算变换矩阵(采用ransac算法从pts中选择一部分点) ==================> H作用：将原图像转换为目标图像
           H, status = cv2.findHomography(np.array(match_kp1_l), # 源图像上的点集
                                          np.array(match_kp2_l), # 目标图像上的点集
                                          cv2.RANSAC, threshold)
        
           return H,status, good_l
        return None,None,None
    
    @staticmethod
    def stitch(src_cv_im_bgr1, dst_cv_im_bgr2, H, threshold=10):
        """
        src_cv_im_bgr1: 源图像， dst_cv_im_bgr2: 目标图像， H: 源图像到目标图像的变换矩阵
        """
        # 获取图像尺寸
        src_h, src_w = src_cv_im_bgr1.shape[:2]
        dst_h, dst_w = dst_cv_im_bgr2.shape[:2]
        # 对源图像做透视变换，由于透视变换会改变图像的尺寸，导致部分图像内容看不到，所以对图像进行扩展：
        # 高度取2图像中最高的，宽度为2者相加
        image = np.zeros((max(src_h, dst_h), src_w + dst_w + src_w , 3), dtype=np.uint8)
        image[:src_h, src_w//3:src_w+src_w//3]= src_cv_im_bgr1
        image = cv2.warpPerspective(image,
                                    H, 
                                    (image.shape[1], image.shape[0])) # 输出图像的尺寸，非图像内容区域用黑色像素填充
        image[0:dst_h, src_w//3:dst_w+src_w//3] = dst_cv_im_bgr2 #  源图像不变。。。。。。。。。
        
        ################################## 去掉黑边 begin######################################
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        # cols = gray.mean(axis=0)  # 计算每一列的平均像素值
        cols = gray.sum(axis=0)  # 计算每一列的平均像素值
        start_col = np.where(cols != 0)[0][0]  # 找到第一个非黑边的列
        end_col = np.where(cols !=0 )[0][-1]   # 找到最后一个非黑边的列
        image = image[:, start_col:end_col]
        ################################## 去掉黑边 begin######################################
        return image
    
    @staticmethod
    def do(src_cv_im_bgr, dst_cv_im_bgr, ratio=0.8, threshold=3):
        H = stitcher.match(src_cv_im_bgr, dst_cv_im_bgr, threshold)
        # H,status, good = stitcher.match_keypoints(kps1,kps2,matches,ratio,threshold)
        if H is not None:
            return stitcher.stitch(src_cv_im_bgr, dst_cv_im_bgr, H)
        return None
#------------------------------------------------------------------------------------- 调用-------------------------------------------------------------------------------------
img_dir = r'./n0101001-03'

img_path_l = os.listdir(img_dir)
img_path_l = sorted(img_path_l,key=lambda a: int(a.split('-')[-1].replace('.jpg','').replace('.png','')))
print("img-path-list:",img_path_l)

im_l = [cv2.imread(os.path.join(img_dir,i)) for i in img_path_l]#[:2]
# left_img = im_l[0]
# other_im_l = im_l[1:]
# for im in other_im_l:
#     stitch_im = stitcher.do(left_img, im)
#     left_img = stitch_im
#     # break



stitch_im = stitcher.do(src_cv_im_bgr=im_l[0],dst_cv_im_bgr=im_l[1])
# stitch_im = stitcher.do(src_cv_im_bgr=im_l[2],dst_cv_im_bgr=stitch_im)
if stitch_im is not None:
    plt.figure(figsize=(20,20))
    plt.imshow(cv2.cvtColor(stitch_im, cv2.COLOR_BGR2RGB))
    # cv2.imwrite(f'/mnt/disk3/projects/expore/accelerated_features/notebooks/results/stitch.jpg',stitch_im)
    plt.show()
# Out:
# img-path-list: ['n0101001-03-01.jpg', 'n0101001-03-02.jpg', 'n0101001-03-03.jpg']
# Loaded LightGlue model
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[9], line 117
#     107 im_l = [cv2.imread(os.path.join(img_dir,i)) for i in img_path_l]#[:2]
#     108 # left_img = im_l[0]
#     109 # other_im_l = im_l[1:]
#     110 # for im in other_im_l:
#     111 #     stitch_im = stitcher.do(left_img, im)
#     112 #     left_img = stitch_im
#     113 #     # break
# --> 117 stitch_im = stitcher.do(src_cv_im_bgr=im_l[0],dst_cv_im_bgr=im_l[1])
#     118 # stitch_im = stitcher.do(src_cv_im_bgr=im_l[2],dst_cv_im_bgr=stitch_im)
#     119 if stitch_im is not None:
#
# Cell In[9], line 95, in stitcher.do(src_cv_im_bgr, dst_cv_im_bgr, ratio, threshold)
#      93 @staticmethod
#      94 def do(src_cv_im_bgr, dst_cv_im_bgr, ratio=0.8, threshold=3):
# ---> 95     H = stitcher.match(src_cv_im_bgr, dst_cv_im_bgr, threshold)
#      96     # H,status, good = stitcher.match_keypoints(kps1,kps2,matches,ratio,threshold)
#      97     if H is not None:
#
# Cell In[9], line 26, in stitcher.match(src_cv_img, dst_cv_img, threshold)
#      15 src_key_info = {
#      16    "keypoints" : kps1,
#      17    "descriptors" : feats1,
#      18    "image_size" : src_cv_img.shape[:2],
#      19 }
#      20 dst_key_info = {
#      21     "keypoints" : kps2,
#      22     "descriptors" : feats2,
#      23     "image_size" : dst_cv_img.shape[:2],
#      24 }
# ---> 26 res = xfeat.match_lighterglue(src_key_info, dst_key_info)
#      28 print(res)
#      30 src_index, dst_index = xfeat.match(feats1, feats2, min_cossim = 0.98)
#
# File ~/anaconda3/envs/xfeat/lib/python3.9/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /mnt/disk3/projects/expore/accelerated_features/modules/xfeat.py:158, in XFeat.match_lighterglue(self, d0, d1, min_conf)
#     148 data = {
#     149 		'keypoints0': d0['keypoints'][None, ...],     # torch.Size([1, 4096, 2])
#     150 		'keypoints1': d1['keypoints'][None, ...],     # torch.Size([1, 4096, 2])
#    (...)
#     154 		'image_size1': torch.tensor(d1['image_size']).to(self.dev)[None, ...]  # torch.Size([1, 2])
#     155 }
#     157 #Dict -> log_assignment: [B x M+1 x N+1] matches0: [B x M] matching_scores0: [B x M] matches1: [B x N] matching_scores1: [B x N] matches: List[[Si x 2]], scores: List[[Si]]
# --> 158 out = self.lighterglue(data, min_conf = min_conf)
#     160 idxs = out['matches'][0]
#     162 return d0['keypoints'][idxs[:, 0]].cpu().numpy(), d1['keypoints'][idxs[:, 1]].cpu().numpy(), out['matches'][0].cpu().numpy()
#
# File ~/anaconda3/envs/xfeat/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/xfeat/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/xfeat/lib/python3.9/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /mnt/disk3/projects/expore/accelerated_features/modules/lighterglue.py:54, in LighterGlue.forward(self, data, min_conf)
#      51 @torch.inference_mode()
#      52 def forward(self, data, min_conf = 0.1):
#      53     self.net.conf.filter_threshold = min_conf
# ---> 54     result = self.net( {   'image0': {'keypoints': data['keypoints0'], 'descriptors': data['descriptors0'], 'image_size': data['image_size0']},
#      55                            'image1': {'keypoints': data['keypoints1'], 'descriptors': data['descriptors1'], 'image_size': data['image_size1']}
#      56                        } )
#      57     return result
#
# File ~/anaconda3/envs/xfeat/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/xfeat/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/xfeat/lib/python3.9/site-packages/kornia/feature/lightglue.py:497, in LightGlue.forward(self, data)
#     477 """Match keypoints and descriptors between two images.
#     478
#     479 Input (dict):
#    (...)
#     494     matches: List[[Si x 2]], scores: List[[Si]]
#     495 """
#     496 with torch.autocast(enabled=self.conf.mp, device_type="cuda"):
# --> 497     return self._forward(data)
#
# File ~/anaconda3/envs/xfeat/lib/python3.9/site-packages/kornia/feature/lightglue.py:513, in LightGlue._forward(self, data)
#     511 kpts0 = normalize_keypoints(kpts0, size0).clone()
#     512 kpts1 = normalize_keypoints(kpts1, size1).clone()
# --> 513 KORNIA_CHECK(torch.all(kpts0 >= -1).item() and torch.all(kpts0 <= 1).item(), "")  # type: ignore
#     514 KORNIA_CHECK(torch.all(kpts1 >= -1).item() and torch.all(kpts1 <= 1).item(), "")  # type: ignore
#     515 if self.conf.add_scale_ori:
#
# File ~/anaconda3/envs/xfeat/lib/python3.9/site-packages/kornia/core/check.py:103, in KORNIA_CHECK(condition, msg, raises)
#     101 if not condition:
#     102     if raises:
# --> 103         raise Exception(f"{condition} not true.\n{msg}")
#     104     return False
#     105 return True
#
# Exception: False not true.
